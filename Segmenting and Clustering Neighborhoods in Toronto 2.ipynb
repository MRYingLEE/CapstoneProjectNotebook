# %%
import pandas as pd

df_toronto=pd.read_csv("toronto.csv",sep="|",index_col="PostalCode",encoding="utf-16")
df_toronto.head()
# Out:
#             Unnamed: 0      Borough                            Neighborhood
# PostalCode
# M1B                  0  Scarborough                          Rouge, Malvern
# M1C                  1  Scarborough  Highland Creek, Rouge Hill, Port Union
# M1E                  2  Scarborough       Guildwood, Morningside, West Hill
# M1G                  3  Scarborough                                  Woburn
# M1H                  4  Scarborough                               Cedarbrae

# %%
df_toronto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 103 entries, M1B to M9W
# Data columns (total 3 columns):
# Unnamed: 0      103 non-null int64
# Borough         103 non-null object
# Neighborhood    103 non-null object
# dtypes: int64(1), object(2)
# memory usage: 3.2+ KB

# %%
df_toronto=df_toronto.loc[:,df_toronto.columns[1:]]
df_toronto.head()
# Out:
#                 Borough                            Neighborhood
# PostalCode
# M1B         Scarborough                          Rouge, Malvern
# M1C         Scarborough  Highland Creek, Rouge Hill, Port Union
# M1E         Scarborough       Guildwood, Morningside, West Hill
# M1G         Scarborough                                  Woburn
# M1H         Scarborough                               Cedarbrae

# %%
df_geo=pd.read_csv("https://cocl.us/Geospatial_data",index_col="Postal Code")

# %%
df_geo.index.rename('PostalCode',inplace=True)
df_geo.head()
# Out:
#              Latitude  Longitude
# PostalCode
# M1B         43.806686 -79.194353
# M1C         43.784535 -79.160497
# M1E         43.763573 -79.188711
# M1G         43.770992 -79.216917
# M1H         43.773136 -79.239476

# %%
df_geo.columns
# Out:
# Index(['Latitude', 'Longitude'], dtype='object')

# %%
df_toronto=df_toronto.join(df_geo, how="left")

# %%
df_toronto.head()
# Out:
#                 Borough                            Neighborhood   Latitude  \
# PostalCode
# M1B         Scarborough                          Rouge, Malvern  43.806686
# M1C         Scarborough  Highland Creek, Rouge Hill, Port Union  43.784535
# M1E         Scarborough       Guildwood, Morningside, West Hill  43.763573
# M1G         Scarborough                                  Woburn  43.770992
# M1H         Scarborough                               Cedarbrae  43.773136
#
#             Longitude
# PostalCode
# M1B        -79.194353
# M1C        -79.160497
# M1E        -79.188711
# M1G        -79.216917
# M1H        -79.239476

# %%
df_toronto.to_csv("toronto_ext.csv",sep="|")

# %%
from google.colab import files


files.download('toronto_ext.csv')
